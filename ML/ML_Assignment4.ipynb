# %% [markdown]
# <a href="https://colab.research.google.com/github/riyapalesha/SPPU_LP3_Lab/blob/main/ML/ML_Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Implement Gradient Descent Algorithm to find the local minima of a function.
# For example, find the local minima of the function y=(x+3)² starting from the point x=2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def objective(x):
    return (x+3)**2

# %%
def derivative(x):
    return 2*(x+3)

# %%
x_list=[]
fx_list=[]
def gradient(start,learning_rate,iterations):
    x=start
    x_list.append(x)
    fx_list.append(objective(x))
    print(f"Iteration 0 -> x = {x}    f(x) = {objective(x)}")
    for i in range(iterations):
        der=derivative(x)
        x=x-(learning_rate*der)
        x_list.append(x)
        fx_list.append(objective(x))
        print(f"Iteration {i+1} -> x = {x}          f(x) = {objective(x)}")

# %%
start=2
learning_rate=0.1
iterations=30
gradient(start,learning_rate,iterations)
# Out:
# Iteration 0 -> x = 2    f(x) = 25
# Iteration 1 -> x = 1.0          f(x) = 16.0
# Iteration 2 -> x = 0.19999999999999996          f(x) = 10.240000000000002
# Iteration 3 -> x = -0.44000000000000017          f(x) = 6.553599999999998
# Iteration 4 -> x = -0.9520000000000001          f(x) = 4.194304
# Iteration 5 -> x = -1.3616000000000001          f(x) = 2.6843545599999996
# Iteration 6 -> x = -1.6892800000000001          f(x) = 1.7179869183999996
# Iteration 7 -> x = -1.951424          f(x) = 1.099511627776
# Iteration 8 -> x = -2.1611392          f(x) = 0.7036874417766399
# Iteration 9 -> x = -2.32891136          f(x) = 0.4503599627370493
# Iteration 10 -> x = -2.463129088          f(x) = 0.28823037615171165
# Iteration 11 -> x = -2.5705032704          f(x) = 0.1844674407370954
# Iteration 12 -> x = -2.6564026163200003          f(x) = 0.11805916207174093
# Iteration 13 -> x = -2.725122093056          f(x) = 0.07555786372591429
# ...

# %%
x_val=np.linspace(-15,15,100)
plt.plot(x_val,objective(x_val))
plt.plot(2,objective(2),"ro")

# %%
x_val=np.linspace(-5,5,100)
plt.plot(x_val,objective(x_val))
plt.plot(x_list,fx_list,'.-',color="red")
plt.plot(x_list[29],fx_list[29],'go')
print(f"Local Minima Occurs at x = {x_list[29]} and f(x) = {fx_list[29]} .")
# Out:
# Local Minima Occurs at x = -2.9922628747544664 and f(x) = 5.986310706507345e-05 .

# %%
def objective2(x):
    return (x**3)-(3*x**2)+1

# %%
def derivative2(x):
    return (3*x**2)-(6*x)

# %%
x_list2=[]
fx_list2=[]
def gradient(start,learning_rate,iterations):
    x=start
    x_list2.append(x)
    fx_list2.append(objective2(x))
    print(f"Iteration 0 -> x = {x}    f(x) = {objective2(x)}")
    for i in range(iterations):
        der=derivative2(x)
        x=x-(learning_rate*der)
        x_list2.append(x)
        fx_list2.append(objective2(x))
        print(f"Iteration {i+1} -> x = {x}          f(x) = {objective2(x)}")

# %%
start=1
learning_rate=0.1
iterations=50
gradient(start,learning_rate,iterations)
# Out:
# Iteration 0 -> x = 1    f(x) = -1
# Iteration 1 -> x = 1.3          f(x) = -1.8730000000000002
# Iteration 2 -> x = 1.5730000000000002          f(x) = -2.5308674829999998
# Iteration 3 -> x = 1.7745013000000003          f(x) = -2.8589175419550985
# Iteration 4 -> x = 1.894545620889493          f(x) = -2.9678108404971617
# Iteration 5 -> x = 1.9544820605337225          f(x) = -2.9938786593967075
# Iteration 6 -> x = 1.9811712593695123          f(x) = -2.9989431107716866
# Iteration 7 -> x = 1.9923621473056858          f(x) = -2.999825435186498
# Iteration 8 -> x = 1.9969273578841402          f(x) = -2.9999717056204975
# Iteration 9 -> x = 1.9987681108147843          f(x) = -2.99999544921656
# Iteration 10 -> x = 1.9995067890606244          f(x) = -2.9999992703488854
# Iteration 11 -> x = 1.9998026426471405          f(x) = -2.999999883157912
# Iteration 12 -> x = 1.9999210453738787          f(x) = -2.999999981298994
# ...

# %%
x_val=np.linspace(-15,15,100)
plt.plot(x_val,objective2(x_val))
plt.plot(1,objective2(1),"ro")

# %%
x_val=np.linspace(-5,5,100)
plt.plot(x_val,objective2(x_val))
plt.plot(x_list2,fx_list2,'.-',color="red")
plt.plot(x_list2[49],fx_list2[49],"go")
print(f"Local Minima Occurs at x = {x_list2[49]} and f(x) = {fx_list2[49]} .")
# Out:
# Local Minima Occurs at x = 2.0 and f(x) = -3.0 .
